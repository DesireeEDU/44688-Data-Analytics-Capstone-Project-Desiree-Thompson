# %% [markdown]
# # Data Analytics Capstone Notebook

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %% [markdown]
# ### Import Data Source

# %%
df = pd.read_csv('bodyfat.csv')

# %% [markdown]
# ### Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
df.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %% [markdown]
# ### Add "BMI" Feature

# %%
# Conversions
df['Height (m)'] = df['Height'] * 0.0254 # 1 inch = 0.0254 meters
df['Weight (kg)'] = df['Weight'] * 0.453592 # 1 pound = 0.453592 kilograms

# Calculate the BMI score
df['BMI'] = df['Weight (kg)']/(df['Height (m)'] ** 2)

# Limit the output to two decimal points
df['BMI'] = df['BMI'].round(2)

# Save the updated DataFrame back to a CSV file
df.to_csv('updated_bodyfat.csv', index=False)

# %% [markdown]
# ### Add "BMI Body Fat" Percentage Feature

# %%
# Calculate the Body Fat Percentage using the given formula
df['BMI Body Fat'] = 1.20 * df['BMI'] + 0.23 * df['Age'] - 16.2

# Limit the output to two decimal points
df['BMI Body Fat'] = df['BMI Body Fat'].round(2)

# Save the updated DataFrame back to a CSV file
df.to_csv('updated_bodyfat.csv', index=False)

# %% [markdown]
# ### Add "Navy Body Fat" Percentage Feature

# %%
# Convert neck and abdomen from centimeters to inches (1 cm = 0.393701 inches)
df['neck_in'] = df['Neck'] * 0.393701
df['abdomen_in'] = df['Abdomen'] * 0.393701


# Calculate the Body Fat Percentage using the given formula
df['Navy Body Fat'] = (
    86.010 * np.log10(df['abdomen_in'] - df['neck_in']) -
    70.041 * np.log10(df['Height']) +
    36.76
)

# Limit the output to two decimal points
df['Navy Body Fat'] = df['Navy Body Fat'].round(2)

# Save the updated DataFrame back to a CSV file
df.to_csv('updated_bodyfat.csv', index=False)

# %% [markdown]
# ### Removed Unnecessary Columns

# %%
# List of columns to remove
columns_to_remove = ['Height (m)', 'Weight (kg)', 'neck_in', 'abdomen_in'] # Enter the name of the columns that need to be removed ['column name']

# Drop the specified columns
df = df.drop(columns=columns_to_remove)

# Save the updated DataFrame back to a CSV file
df.to_csv('updated_bodyfat.csv', index=False)

# %% [markdown]
# ### Transformed Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Density        252 non-null    float64
#  1   BodyFat        252 non-null    float64
#  2   Age            252 non-null    int64
#  3   Weight         252 non-null    float64
#  4   Height         252 non-null    float64
#  5   Neck           252 non-null    float64
#  6   Chest          252 non-null    float64
#  7   Abdomen        252 non-null    float64
#  8   Hip            252 non-null    float64
#  9   Thigh          252 non-null    float64
#  10  Knee           252 non-null    float64
#  11  Ankle          252 non-null    float64
#  12  Biceps         252 non-null    float64
#  13  Forearm        252 non-null    float64
#  14  Wrist          252 non-null    float64
#  15  BMI            252 non-null    float64
#  16  BMI Body Fat   252 non-null    float64
# ...

# %% [markdown]
# ### Updated Description

# %%
df.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %% [markdown]
# ### Correlation Summary

# %%
df.corr()
# Out:
#                 Density   BodyFat       Age    Weight    Height      Neck  \
# Density        1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966
# BodyFat       -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592
# Age           -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505
# Weight        -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716
# Height         0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710
# Neck          -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000
# Chest         -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835
# Abdomen       -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077
# Hip           -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958
# Thigh         -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697
# Knee          -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405
# Ankle         -0.264890  0.265970 -0.105058  0.613685  0.264744  0.477892
# ...

# %% [markdown]
# ### Body Fat Distribution

# %%
# Distribution of a specific variable with customized colors
sns.histplot(df['BodyFat'], bins=30, kde=True)
plt.title('Distribution of Body Fat')
plt.xlabel('Body Fat')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
from pandas.plotting import scatter_matrix
attributes = ['Weight', 'Neck', 'Thigh', 'Knee', 'Ankle',  'Biceps', 'Forearm', 'Wrist', 'BodyFat']
scatter_matrix(df[attributes])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Neck', ylabel='Weight'>,
#         <Axes: xlabel='Thigh', ylabel='Weight'>,
#         <Axes: xlabel='Knee', ylabel='Weight'>,
#         <Axes: xlabel='Ankle', ylabel='Weight'>,
#         <Axes: xlabel='Biceps', ylabel='Weight'>,
#         <Axes: xlabel='Forearm', ylabel='Weight'>,
#         <Axes: xlabel='Wrist', ylabel='Weight'>,
#         <Axes: xlabel='BodyFat', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Neck'>,
#         <Axes: xlabel='Neck', ylabel='Neck'>,
#         <Axes: xlabel='Thigh', ylabel='Neck'>,
#         <Axes: xlabel='Knee', ylabel='Neck'>,
#         <Axes: xlabel='Ankle', ylabel='Neck'>,
#         <Axes: xlabel='Biceps', ylabel='Neck'>,
#         <Axes: xlabel='Forearm', ylabel='Neck'>,
#         <Axes: xlabel='Wrist', ylabel='Neck'>,
#         <Axes: xlabel='BodyFat', ylabel='Neck'>],
#        [<Axes: xlabel='Weight', ylabel='Thigh'>,
# ...

# %% [markdown]
# ### Individual Correlation Plots

# %%
density = df['Density']
body_fat = df['BodyFat']

plt.scatter(body_fat, density)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Density')
plt.show()

# %%
age = df['Age']
body_fat = df['BodyFat']

plt.scatter(body_fat, age)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Age')
plt.show()

# %%
height = df['Height']
body_fat = df['BodyFat']

plt.scatter(body_fat, height)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Height')
plt.show()

# %%
neck = df['Neck']
body_fat = df['BodyFat']

plt.scatter(body_fat, neck)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Neck')
plt.show()

# %%
biceps = df['Biceps']
body_fat = df['BodyFat']

plt.scatter(body_fat, biceps)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Biceps')
plt.show()

# %%
abdomen = df['Abdomen']
body_fat = df['BodyFat']

plt.scatter(body_fat, abdomen)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Abdomen')
plt.show()

# %%
hip = df['Hip']
body_fat = df['BodyFat']

plt.scatter(body_fat, hip)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Hip')
plt.show()

# %%
thigh = df['Thigh']
body_fat = df['BodyFat']

plt.scatter(body_fat, thigh)
plt.xlabel('Body Fat Percentage')
plt.ylabel('Thigh')
plt.show()

# %% [markdown]
# ### Correlation Matrix for Model Features

# %%
# calculate correlation matrix
corr = df[model_attributes].corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <Axes: >

# %% [markdown]
# ### Train/Test Split

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2, random_state=123)
print('Train size: ', len(train_set), 'Test size: ', len(test_set))
# Out:
# Train size:  201 Test size:  51

# %% [markdown]
# ### Train and Evaluate a Linear Regression Model

# %% [markdown]
# #### Feature: Abdomen

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

X = train_set[['Abdomen']]
y = train_set['BodyFat']

X_test = test_set[['Abdomen']]
y_test = test_set['BodyFat']

lr_model = LinearRegression()
lr_model.fit(X,y)

y_pred = lr_model.predict(X)

print('Results for linear regression on training data')
print('Input: Abdomen')
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = lr_model.predict(X_test)
print()
print('Results for linear regression on test data')
print('Input: Abdomen')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for linear regression on training data
# Input: Abdomen
#  Default settings
# Internal parameters:
#  Bias is  -38.674262452298244
#  Coefficients [0.62767975]
#  Score 0.670650834983292
# MAE is  3.860031646764518
# RMSE is  4.79848455229992
# MSE is  23.02545399866096
# R^2  0.670650834983292
#
# Results for linear regression on test data
# Input: Abdomen
# MAE is  4.1740207207627655
# RMSE is  5.122348257913785
# MSE is  26.23845167535239
# R^2  0.6175708364932893

# %% [markdown]
# #### Features: Neck and Abdomen

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

X = train_set[['Neck', 'Abdomen']]
y = train_set['BodyFat']

X_test = test_set[['Neck', 'Abdomen']]
y_test = test_set['BodyFat']

lr_model = LinearRegression()
lr_model.fit(X,y)

y_pred = lr_model.predict(X)

print('Results for linear regression on training data')
print('Input: Neck, Abdomen')
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = lr_model.predict(X_test)
print()
print('Results for linear regression on test data')
print('Input: Neck, Abdomen')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for linear regression on training data
# Input: Neck, Abdomen
#  Default settings
# Internal parameters:
#  Bias is  -18.12619235098135
#  Coefficients [-0.92830639  0.78639553]
#  Score 0.7014194766720243
# MAE is  3.681394512814981
# RMSE is  4.568846372091579
# MSE is  20.87435717177438
# R^2  0.7014194766720243
#
# Results for linear regression on test data
# Input: Neck, Abdomen
# MAE is  3.8633233725109792
# RMSE is  4.756169511126821
# MSE is  22.62114841857234
# R^2  0.6702935457353131

# %% [markdown]
# #### Features: Neck, Biceps, Abdomen, Hip, Thigh

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

X = train_set[['Neck', 'Biceps', 'Abdomen', 'Hip', 'Thigh']]
y = train_set['BodyFat']

X_test = test_set[['Neck', 'Biceps', 'Abdomen', 'Hip', 'Thigh']]
y_test = test_set['BodyFat']

lr_model = LinearRegression()
lr_model.fit(X,y)

y_pred = lr_model.predict(X)

print('Results for linear regression on training data')
print('Input: Neck, Biceps, Abdomen, Hip, Thigh')
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = lr_model.predict(X_test)
print()
print('Results for linear regression on test data')
print('Input: Neck, Biceps, Abdomen, Hip, Thigh')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for linear regression on training data
# Input: Neck, Biceps, Abdomen, Hip, Thigh
#  Default settings
# Internal parameters:
#  Bias is  -4.803689460570681
#  Coefficients [-0.84997379  0.17797804  0.9659537  -0.48052254  0.15687713]
#  Score 0.7252725689376585
# MAE is  3.5702089598066054
# RMSE is  4.382549501696607
# MSE is  19.206740134821178
# R^2  0.7252725689376585
#
# Results for linear regression on test data
# Input: Neck, Biceps, Abdomen, Hip, Thigh
# MAE is  3.6969048020270634
# RMSE is  4.604982679628679
# MSE is  21.20586547968013
# R^2  0.6909214957814012

# %% [markdown]
# ### Polynomial Regression

# %% [markdown]
# #### Degree 3: Abdomen

# %%
# Import model and metric functions
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.preprocessing import PolynomialFeatures
power = 3
poly_process = PolynomialFeatures(degree=power, include_bias=False)

# Predict on the feature height and use weight as target feature
X = train_set[['Abdomen']]
y = train_set['BodyFat']
X_poly = poly_process.fit_transform(X)

# Test the trained model on height with weigh as the target feature
X_test = test_set[['Abdomen']]
y_test = test_set['BodyFat']
X_poly_test = poly_process.fit_transform(X_test)

# Create a instance of a decision tree model
# Train the model on the training data
lr_model = LinearRegression()
lr_model.fit(X_poly,y)

# Get the predictions on the model on the training data
y_pred = lr_model.predict(X_poly)

# Print the internal parameters for the regression
# Bias plus a coefficient for each of the input parameters. 
# Use the model to conpute on the training data. This should be the same R2
# Compute the standard metrics. RMSE gives a good estimate of the spread of the predictions
print('Results for linear regression on training data')
print('Polynomial regression with degree ', power)
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X_poly,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = lr_model.predict(X_poly_test)
print()
print('Results for linear regression on test data')
print('Polynomial regression with degree ', power)
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for linear regression on training data
# Polynomial regression with degree  3
#  Default settings
# Internal parameters:
#  Bias is  26.830159894137786
#  Coefficients [-1.82241682e+00  2.91164080e-02 -1.10747866e-04]
#  Score 0.7020950033716742
# MAE is  3.673081305202678
# RMSE is  4.563675027765126
# MSE is  20.827129759047022
# R^2  0.7020950033716742
#
# Results for linear regression on test data
# Polynomial regression with degree  3
# MAE is  4.212490612128771
# RMSE is  5.179875997700097
# MSE is  26.831115351549577
# R^2  0.608932679153319

# %%
#### Degree 3: Neck and Abdomen

# %%
# Import model and metric functions
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.preprocessing import PolynomialFeatures
power = 3
poly_process = PolynomialFeatures(degree=power, include_bias=False)

# Predict on the feature height and use weight as target feature
X = train_set[['Neck', 'Abdomen']]
y = train_set['BodyFat']
X_poly = poly_process.fit_transform(X)

# Test the trained model on height with weigh as the target feature
X_test = test_set[['Neck', 'Abdomen']]
y_test = test_set['BodyFat']
X_poly_test = poly_process.fit_transform(X_test)

# Create a instance of a decision tree model
# Train the model on the training data
lr_model = LinearRegression()
lr_model.fit(X_poly,y)

# Get the predictions on the model on the training data
y_pred = lr_model.predict(X_poly)

# Print the internal parameters for the regression
# Bias plus a coefficient for each of the input parameters. 
# Use the model to conpute on the training data. This should be the same R2
# Compute the standard metrics. RMSE gives a good estimate of the spread of the predictions
print('Results for linear regression on training data')
print('Polynomial regression with degree ', power)
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X_poly,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = lr_model.predict(X_poly_test)
print()
print('Results for linear regression on test data')
print('Polynomial regression with degree ', power)
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))

# %% [markdown]
#  #### Degree 3: Neck, Biceps, Abdomen, Hip, Thigh

# %%
# Import model and metric functions
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.preprocessing import PolynomialFeatures
power = 3
poly_process = PolynomialFeatures(degree=power, include_bias=False)

# Predict on the feature height and use weight as target feature
X = train_set[['Neck', 'Biceps', 'Abdomen', 'Hip', 'Thigh']]
y = train_set['BodyFat']
X_poly = poly_process.fit_transform(X)

# Test the trained model on height with weigh as the target feature
X_test = test_set[['Neck', 'Biceps', 'Abdomen', 'Hip', 'Thigh']]
y_test = test_set['BodyFat']
X_poly_test = poly_process.fit_transform(X_test)

# Create a instance of a decision tree model
# Train the model on the training data
lr_model = LinearRegression()
lr_model.fit(X_poly,y)

# Get the predictions on the model on the training data
y_pred = lr_model.predict(X_poly)

# Print the internal parameters for the regression
# Bias plus a coefficient for each of the input parameters. 
# Use the model to conpute on the training data. This should be the same R2
# Compute the standard metrics. RMSE gives a good estimate of the spread of the predictions
print('Results for linear regression on training data')
print('Polynomial regression with degree ', power)
print(' Default settings')
print('Internal parameters:')
print(' Bias is ', lr_model.intercept_)
print(' Coefficients', lr_model.coef_)
print(' Score', lr_model.score(X_poly,y))
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y, y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = lr_model.predict(X_poly_test)
print()
print('Results for linear regression on test data')
print('Polynomial regression with degree ', power)
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for linear regression on training data
# Polynomial regression with degree  3
#  Default settings
# Internal parameters:
#  Bias is  -581.4536661589957
#  Coefficients [ 8.59077613e+01 -5.88555233e+01  1.44843120e+00 -8.88701348e+01
#   1.51134547e+02  8.74585317e-03  5.18126374e+00  2.75475079e+00
#  -3.05424902e+00 -4.92701720e+00 -3.32335546e+00 -1.12973754e+00
#  -1.11349858e-01  4.16895095e+00  4.00689737e-02 -2.23619063e+00
#   2.39161940e+00  3.88202428e+00 -4.48277146e+00 -1.47237119e-01
#  -9.73769017e-03 -2.31180877e-01 -5.02111496e-02  9.78969083e-02
#   5.74392878e-02  1.41708747e-01  7.84486255e-02 -1.75088678e-02
#  -3.74441346e-02  8.35512228e-03 -6.89309723e-03 -3.62721708e-02
#  -2.76817164e-02  3.96699967e-02  7.65606378e-03 -6.01842579e-03
#  -3.93985084e-02  3.34593875e-02 -2.01946714e-02 -4.34893957e-03
#  -3.38164967e-02  8.09407459e-02  2.79629043e-02 -6.35958819e-02
#  -2.10862617e-02 -6.11733824e-04 -4.00714043e-03  5.44588998e-03
# ...

# %% [markdown]
# # Results
# Basic results for our regression models to predict body fat on
# the Howell data.
# | Model | Training Features | Set | RMSE | R2 |
# |:---|:---|:---|:---|:---|
# |Linear Regression|Abdomen|Training|4.80|67.07|
# |Linear Regression|Abdomen|Test|5.12|61.76|
# |Linear Regression|Neck, Abdomen|Training|4.57|70.14|
# |Linear Regression|Neck, Abdomen|Test|4.75|67.02|
# |Linear Regression|Neck, Biceps, Abdomen, Hip, Thigh|Training|4.38|72.53|
# |Linear Regression|Neck, Biceps, Abdomen, Hip, Thigh|Test|4.60|69.09|
# |Polynomial Regression degree 3|Abdomen|Training|4.56|70.21|
# |Polynomial Regression degree 3|Abdomen|Test|5.18|60.89|
# |Polynomial Regression degree 3|Neck, Abdomen|Training|0|0|
# |Polynomial Regression degree 3|Neck, Abdomen|Test|0|0|
# |Polynomial Regression degree 3|Neck, Biceps, Abdomen, Hip, Thigh|Training|3.63|81.16|
# |Polynomial Regression degree 3|Neck, Biceps, Abdomen, Hip, Thigh|Test|5.14|61.45|
#
#
#
# |Linear Regression|Height|Test|5.31|86.77|
# |Linear Regression|Height,Age|Training|4.88|89.04|
# |Linear Regression|Height,Age|Test|5.18|87.39|
# |Polynomial Regression degree 3|Height|Training|3.82|83.28|
# |Polynomial Regression degree 3|Height|Test|4.31|91.30|
# |Polynomial Regression degree 8|Height|Training|3.67|93.79|
# |Polynomial Regression degree 8|Height|Test|4.26|91.50|
# |Elastic Net degree 8|Height|Training|3.76|93.49|
# |Elastic Net degree 8|Height|Test|4.22|91.66|
